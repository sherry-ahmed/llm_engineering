# %%
import os
import re
import google.generativeai as genai

# %%
# ✅ Initialize Gemini client
api_key = os.getenv('GEMINI_API_KEY')
genai.configure(api_key=api_key)

# %%
# Input & Output directories
input_dir = "converted_html"
output_dir = "converted_html_arabic_gemini"
os.makedirs(output_dir, exist_ok=True)

def extract_and_replace_images(html_content):
    """Replace <img> tags with placeholders and return (processed_html, images_dict)."""
    images = {}
    def replacer(match):
        placeholder = f"[[IMG_TAG_{len(images)}]]"
        images[placeholder] = match.group(0)
        return placeholder
    processed_html = re.sub(r"<img[^>]*>", replacer, html_content, flags=re.IGNORECASE)
    return processed_html, images

def restore_images(translated_html, images):
    """Put back the original <img> tags in the translated content."""
    for placeholder, img_tag in images.items():
        translated_html = translated_html.replace(placeholder, img_tag)
    return translated_html

def enforce_rtl(html):
    """Force <html> tag to have lang='ar' and dir='rtl'."""
    html = re.sub(
        r"<html[^>]*>",
        '<html lang="ar" dir="rtl">',
        html,
        count=1,
        flags=re.IGNORECASE,
    )
    return html

def translate_to_arabic(text):
    """Send text to Gemini for Arabic translation with RTL enforcement."""
    prompt = f"""
Translate the following HTML content into **Arabic**.  
⚠️ Important formatting rules:
- Keep the full HTML structure unchanged.  
- Translate ONLY visible text inside tags.  
- Do not touch HTML attributes, placeholders like [[IMG_TAG_#]], or CSS.  
- Ensure the <html> tag becomes: <html lang="ar" dir="rtl">.  
- Keep tables, lists, and inline formatting intact.  

Example of expected output:
<!DOCTYPE html>
<html lang="ar" dir="rtl">
...
</html>

Content to translate:
{text}
"""
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content(prompt)
    return response.text.strip()

# 🚀 Walk through chapters
for chapter in sorted(os.listdir(input_dir)):
    chapter_path = os.path.join(input_dir, chapter)
    if os.path.isdir(chapter_path):  # Only process folders (chap0, chap1, ...)
        out_chapter_path = os.path.join(output_dir, chapter)
        os.makedirs(out_chapter_path, exist_ok=True)

        for filename in os.listdir(chapter_path):
            if filename.endswith(".html"):
                input_file = os.path.join(chapter_path, filename)
                output_file = os.path.join(out_chapter_path, filename)

                with open(input_file, "r", encoding="utf-8") as f:
                    html_content = f.read()

                # 🚨 Extract and replace <img> tags
                safe_html, images = extract_and_replace_images(html_content)

                # 🌍 Translate with Gemini
                translated_html = translate_to_arabic(safe_html)

                # 🔄 Restore <img> tags
                final_html = restore_images(translated_html, images)

                # ✅ Ensure RTL alignment in <html>
                final_html = enforce_rtl(final_html)

                # Save Arabic version
                with open(output_file, "w", encoding="utf-8") as f:
                    f.write(final_html)

                print(f"✅ Translated: {input_file} → {output_file}")

print("🎉 All files translated into Arabic (RTL enforced, images preserved) using Gemini!")
# Out:
# ✅ Translated: converted_html/chap0/Introduction to Forex Markets.html → converted_html_arabic_gemini/chap0/Introduction to Forex Markets.html
# ✅ Translated: converted_html/chap0/Key Concepts.html → converted_html_arabic_gemini/chap0/Key Concepts.html
# ✅ Translated: converted_html/chap0/Market Participants.html → converted_html_arabic_gemini/chap0/Market Participants.html
# ✅ Translated: converted_html/chap0/Global Market Influences.html → converted_html_arabic_gemini/chap0/Global Market Influences.html
# ✅ Translated: converted_html/chap02/Demo Accounts and Real Accounts.html → converted_html_arabic_gemini/chap02/Demo Accounts and Real Accounts.html
# ✅ Translated: converted_html/chap02/Choosing a Broker.html → converted_html_arabic_gemini/chap02/Choosing a Broker.html
# ✅ Translated: converted_html/chap02/Types of Forex Brokers.html → converted_html_arabic_gemini/chap02/Types of Forex Brokers.html
# ✅ Translated: converted_html/chap02/Trading Platforms and Tools.html → converted_html_arabic_gemini/chap02/Trading Platforms and Tools.html
# ✅ Translated: converted_html/chap03/Carry Trades.html → converted_html_arabic_gemini/chap03/Carry Trades.html
# ✅ Translated: converted_html/chap03/Central Banks and Interest Rates.html → converted_html_arabic_gemini/chap03/Central Banks and Interest Rates.html
# ✅ Translated: converted_html/chap03/Geopolitical and Economic Events.html → converted_html_arabic_gemini/chap03/Geopolitical and Economic Events.html
# ✅ Translated: converted_html/chap03/Economic Indicators and Their Impact on Currencies.html → converted_html_arabic_gemini/chap03/Economic Indicators and Their Impact on Currencies.html
# ✅ Translated: converted_html/chap04/Volume Analysis.html → converted_html_arabic_gemini/chap04/Volume Analysis.html
# ✅ Translated: converted_html/chap04/Technical Indicators Overview.html → converted_html_arabic_gemini/chap04/Technical Indicators Overview.html
# ✅ Translated: converted_html/chap04/Candlestick Patterns and Their Meanings.html → converted_html_arabic_gemini/chap04/Candlestick Patterns and Their Meanings.html
# ✅ Translated: converted_html/chap04/Basics of Price Charts.html → converted_html_arabic_gemini/chap04/Basics of Price Charts.html
# ✅ Translated: converted_html/chap04/Support and Resistance Basics.html → converted_html_arabic_gemini/chap04/Support and Resistance Basics.html
# ✅ Translated: converted_html/chap05/Advanced Candlestick Patterns.html → converted_html_arabic_gemini/chap05/Advanced Candlestick Patterns.html
# ✅ Translated: converted_html/chap05/Chart Patterns.html → converted_html_arabic_gemini/chap05/Chart Patterns.html
# ✅ Translated: converted_html/chap05/Moving Average Strategies.html → converted_html_arabic_gemini/chap05/Moving Average Strategies.html
# ✅ Translated: converted_html/chap05/Fibonacci Analysis.html → converted_html_arabic_gemini/chap05/Fibonacci Analysis.html
# ✅ Translated: converted_html/chap06/Supply and Demand (SK) Trading.html → converted_html_arabic_gemini/chap06/Supply and Demand (SK) Trading.html
# ✅ Translated: converted_html/chap06/Harmonic Patterns.html → converted_html_arabic_gemini/chap06/Harmonic Patterns.html
# ✅ Translated: converted_html/chap06/Smart Money Concepts (SMC).html → converted_html_arabic_gemini/chap06/Smart Money Concepts (SMC).html
# ✅ Translated: converted_html/chap06/Heikin-Ashi Candlesticks.html → converted_html_arabic_gemini/chap06/Heikin-Ashi Candlesticks.html
# ✅ Translated: converted_html/chap07/Moving Average Applications.html → converted_html_arabic_gemini/chap07/Moving Average Applications.html
# ✅ Translated: converted_html/chap07/Ichimoku Cloud.html → converted_html_arabic_gemini/chap07/Ichimoku Cloud.html
# ✅ Translated: converted_html/chap07/ADX and ATR (Average True Range).html → converted_html_arabic_gemini/chap07/ADX and ATR (Average True Range).html
# ✅ Translated: converted_html/chap07/Oscillators RSI, Stochastic, MACD.html → converted_html_arabic_gemini/chap07/Oscillators RSI, Stochastic, MACD.html
# ✅ Translated: converted_html/chap08/Naked Price Action Trading.html → converted_html_arabic_gemini/chap08/Naked Price Action Trading.html
# ✅ Translated: converted_html/chap08/Market Structure Analysis.html → converted_html_arabic_gemini/chap08/Market Structure Analysis.html
# ✅ Translated: converted_html/chap08/SupportResistance Zones and Trendlines.html → converted_html_arabic_gemini/chap08/SupportResistance Zones and Trendlines.html
# ✅ Translated: converted_html/chap08/Price Action Patterns.html → converted_html_arabic_gemini/chap08/Price Action Patterns.html
# ✅ Translated: converted_html/chap09/Swing Trading.html → converted_html_arabic_gemini/chap09/Swing Trading.html
# ✅ Translated: converted_html/chap09/Forex Trading Strategies and Styles.html → converted_html_arabic_gemini/chap09/Forex Trading Strategies and Styles.html
# ✅ Translated: converted_html/chap09/Position Trading.html → converted_html_arabic_gemini/chap09/Position Trading.html
# ✅ Translated: converted_html/chap09/Day Trading.html → converted_html_arabic_gemini/chap09/Day Trading.html
# ✅ Translated: converted_html/chap09/Algorithmic and Automated Trading.html → converted_html_arabic_gemini/chap09/Algorithmic and Automated Trading.html
# ✅ Translated: converted_html/chap1/Currency Pairs and Pricing.html → converted_html_arabic_gemini/chap1/Currency Pairs and Pricing.html
# ✅ Translated: converted_html/chap1/History and Evolution of Forex Market.html → converted_html_arabic_gemini/chap1/History and Evolution of Forex Market.html
# ✅ Translated: converted_html/chap1/Forex Market Hours.html → converted_html_arabic_gemini/chap1/Forex Market Hours.html
# ✅ Translated: converted_html/chap1/Overview of Forex Market Structure.html → converted_html_arabic_gemini/chap1/Overview of Forex Market Structure.html
# ✅ Translated: converted_html/chap1/Key Forex Terminology.html → converted_html_arabic_gemini/chap1/Key Forex Terminology.html
# ✅ Translated: converted_html/chap1/Market Participants and Their Roles.html → converted_html_arabic_gemini/chap1/Market Participants and Their Roles.html
# ✅ Translated: converted_html/chap10/Leverage and Margin Risks.html → converted_html_arabic_gemini/chap10/Leverage and Margin Risks.html
# ✅ Translated: converted_html/chap10/Trading Psychology and Discipline.html → converted_html_arabic_gemini/chap10/Trading Psychology and Discipline.html
# ✅ Translated: converted_html/chap10/Stop Losses and Take Profits.html → converted_html_arabic_gemini/chap10/Stop Losses and Take Profits.html
# ✅ Translated: converted_html/chap10/Position Sizing and Risk Per Trade.html → converted_html_arabic_gemini/chap10/Position Sizing and Risk Per Trade.html
# ✅ Translated: converted_html/chap11/Creating a Trading Plan.html → converted_html_arabic_gemini/chap11/Creating a Trading Plan.html
# ✅ Translated: converted_html/chap11/Reviewing and Adjusting Strategies.html → converted_html_arabic_gemini/chap11/Reviewing and Adjusting Strategies.html
# ✅ Translated: converted_html/chap11/Backtesting and Optimization.html → converted_html_arabic_gemini/chap11/Backtesting and Optimization.html
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:65, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      64 try:
# ---> 65     return callable_(*args, **kwargs)
#      66 except grpc.RpcError as exc:
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/grpc/_interceptor.py:332, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
# --> 332 return call.result(), call
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/grpc/_channel.py:440, in _InactiveRpcError.result(self, timeout)
#     439 """See grpc.Future.result."""
# --> 440 raise self
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/grpc/_channel.py:1192, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1189 state, call = self._blocking(
#    1190     request, timeout, metadata, credentials, wait_for_ready, compression
#    1191 )
# -> 1192 return _end_unary_response_blocking(state, call, True, None)
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/grpc/_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B2a00:1450:4018:80e::200a%5D:443 {grpc_status:8, grpc_message:"You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits."}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[10], line 76
#      73 safe_html, images = extract_and_replace_images(html_content)
#      75 # 🌍 Translate with Gemini
# ---> 76 translated_html = translate_to_arabic(safe_html)
#      78 # 🔄 Restore <img> tags
#      79 final_html = restore_images(translated_html, images)
#
# Cell In[10], line 54, in translate_to_arabic(text)
#      35     prompt = f"""
#      36 Translate the following HTML content into **Arabic**.
#      37 ⚠️ Important formatting rules:
#    (...)     51 {text}
#      52 """
#      53     model = genai.GenerativeModel("gemini-1.5-flash")
# ---> 54     response = model.generate_content(prompt)
#      55     return response.text.strip()
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:113, in _GapicCallable.__call__(self, timeout, retry, *args, **kwargs)
#     110     metadata.extend(self._metadata)
#     111     kwargs["metadata"] = metadata
# --> 113 return wrapped_func(*args, **kwargs)
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/api_core/retry.py:349, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     345 target = functools.partial(func, *args, **kwargs)
#     346 sleep_generator = exponential_sleep_generator(
#     347     self._initial, self._maximum, multiplier=self._multiplier
#     348 )
# --> 349 return retry_target(
#     350     target,
#     351     self._predicate,
#     352     sleep_generator,
#     353     self._timeout,
#     354     on_error=on_error,
#     355 )
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/api_core/retry.py:191, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189 for sleep in sleep_generator:
#     190     try:
# --> 191         return target()
#     193     # pylint: disable=broad-except
#     194     # This function explicitly must deal with broad exceptions.
#     195     except Exception as exc:
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/Desktop/udemy-course/llm_engineering/llms_venv/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:67, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      65     return callable_(*args, **kwargs)
#      66 except grpc.RpcError as exc:
# ---> 67     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-flash"
#   }
#   quota_value: 50
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
